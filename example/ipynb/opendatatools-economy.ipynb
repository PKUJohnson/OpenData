# %% [markdown]
# # OpenDataTools 支持宏观经济数据

# %%
# 导入coin接口
from opendatatools import economy

# 注：数据来源 - 国家统计局

# %% [markdown]
# ## 数据字典和规范

# %%
# 获取地区列表
df = economy.get_region_map();
df
# Out:
#       region    name
# 0         北京  110000
# 1         天津  120000
# 2        河北省  130000
# 3        山西省  140000
# 4     内蒙古自治区  150000
# 5        辽宁省  210000
# 6        吉林省  220000
# 7       黑龙江省  230000
# 8         上海  310000
# 9        江苏省  320000
# 10       浙江省  330000
# 11       安徽省  340000
# 12       福建省  350000
# 13       江西省  360000
# 14       山东省  370000
# 15       河南省  410000
# 16       湖北省  420000
# 17       湖南省  430000
# 18       广东省  440000
# 19   广西壮族自治区  450000
# 20       海南省  460000
# 21        重庆  500000
# 22       四川省  510000
# 23       贵州省  520000
# 24       云南省  530000
# 25     西藏自治区  540000
# 26       陕西省  610000
# 27       甘肃省  620000
# 28       青海省  630000
# 29   宁夏回族自治区  640000
# 30  新疆维吾尔自治区  650000

# %%
# 获取指标集合
df = economy.get_indicator_map()
df.head(20)
# Out:
#    indicator                name
# 0    A020101           国民总收入(亿元)
# 1    A020102          国内生产总值(亿元)
# 2    A020103         第一产业增加值(亿元)
# 3    A020104         第二产业增加值(亿元)
# 4    A020105         第三产业增加值(亿元)
# 5    A020106         人均国内生产总值(元)
# 6    A030101           年末总人口(万人)
# 7    A030102            男性人口(万人)
# 8    A030103            女性人口(万人)
# 9    A030104            城镇人口(万人)
# 10   A030105            乡村人口(万人)
# 11   A030301           年末总人口(万人)
# 12   A030302         0-14岁人口(万人)
# 13   A030303        15-64岁人口(万人)
# 14   A030304        65岁及以上人口(万人)
# 15   A030305             总抚养比(%)
# 16   A030306            少儿抚养比(%)
# 17   A030307            老年抚养比(%)
# 18   A010801  新建住宅销售价格指数(上月=100)
# 19   A010802  新建住宅销售价格指数(上年=100)

# %%
#大中城市列表（房价数据使用）
df = economy.get_city_map()
df.head(20)
# Out:
#     city    name
# 0     北京  110000
# 1     天津  120000
# 2    石家庄  130100
# 3     唐山  130200
# 4    秦皇岛  130300
# 5     太原  140100
# 6   呼和浩特  150100
# 7     包头  150200
# 8     沈阳  210100
# 9     大连  210200
# 10    丹东  210600
# 11    锦州  210700
# 12    长春  220100
# 13    吉林  220200
# 14   哈尔滨  230100
# 15   牡丹江  231000
# 16    上海  310000
# 17    南京  320100
# 18    无锡  320200
# 19    徐州  320300

# %% [markdown]
# ## 数据接口 - 年度数据

# %%
# 年度GDP数据
df, msg = economy.get_gdp_y()
df[df.date=='2016']
# Out:
#      date indicator indicator_name  strvalue     value
# 0    2016   A020101      国民总收入(亿元)  740598.7  740598.7
# 36   2016   A020102     国内生产总值(亿元)  743585.5  743585.5
# 72   2016   A020103    第一产业增加值(亿元)   63672.8   63672.8
# 108  2016   A020104    第二产业增加值(亿元)  296547.7  296547.7
# 144  2016   A020105    第三产业增加值(亿元)  383365.0  383365.0
# 180  2016   A020106    人均国内生产总值(元)     53935   53935.0

# %%
economy.disp_result(df, date_format="%Y")
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 年度人口数据
df,msg = economy.get_population_size_y()
df.head(20)
# Out:
#     date indicator indicator_name strvalue     value
# 0   2016   A030101      年末总人口(万人)   138271  138271.0
# 1   2015   A030101      年末总人口(万人)   137462  137462.0
# 2   2014   A030101      年末总人口(万人)   136782  136782.0
# 3   2013   A030101      年末总人口(万人)   136072  136072.0
# 4   2012   A030101      年末总人口(万人)   135404  135404.0
# 5   2011   A030101      年末总人口(万人)   134735  134735.0
# 6   2010   A030101      年末总人口(万人)   134091  134091.0
# 7   2009   A030101      年末总人口(万人)   133450  133450.0
# 8   2008   A030101      年末总人口(万人)   132802  132802.0
# 9   2007   A030101      年末总人口(万人)   132129  132129.0
# 10  2006   A030101      年末总人口(万人)   131448  131448.0
# 11  2005   A030101      年末总人口(万人)   130756  130756.0
# 12  2004   A030101      年末总人口(万人)   129988  129988.0
# 13  2003   A030101      年末总人口(万人)   129227  129227.0
# 14  2002   A030101      年末总人口(万人)   128453  128453.0
# 15  2001   A030101      年末总人口(万人)   127627  127627.0
# 16  2000   A030101      年末总人口(万人)   126743  126743.0
# 17  1999   A030101      年末总人口(万人)   125786  125786.0
# 18  1998   A030101      年末总人口(万人)   124761  124761.0
# 19  1997   A030101      年末总人口(万人)   123626  123626.0

# %%
economy.disp_result(df, date_format="%Y")
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 年度人口结构数据
df, msg = economy.get_population_structure_y()
df = df[(df['indicator'] == 'A030301') | (df['indicator'] == 'A030302') | (df['indicator'] == 'A030303') | (df['indicator'] == 'A030304')]
df = df[df['date'] >= '1990']
df.head(20)
# Out:
#     date indicator indicator_name strvalue     value
# 0   2016   A030301      年末总人口(万人)   138271  138271.0
# 1   2015   A030301      年末总人口(万人)   137462  137462.0
# 2   2014   A030301      年末总人口(万人)   136782  136782.0
# 3   2013   A030301      年末总人口(万人)   136072  136072.0
# 4   2012   A030301      年末总人口(万人)   135404  135404.0
# 5   2011   A030301      年末总人口(万人)   134735  134735.0
# 6   2010   A030301      年末总人口(万人)   134091  134091.0
# 7   2009   A030301      年末总人口(万人)   133450  133450.0
# 8   2008   A030301      年末总人口(万人)   132802  132802.0
# 9   2007   A030301      年末总人口(万人)   132129  132129.0
# 10  2006   A030301      年末总人口(万人)   131448  131448.0
# 11  2005   A030301      年末总人口(万人)   130756  130756.0
# 12  2004   A030301      年末总人口(万人)   129988  129988.0
# 13  2003   A030301      年末总人口(万人)   129227  129227.0
# 14  2002   A030301      年末总人口(万人)   128453  128453.0
# 15  2001   A030301      年末总人口(万人)   127627  127627.0
# 16  2000   A030301      年末总人口(万人)   126743  126743.0
# 17  1999   A030301      年末总人口(万人)   125786  125786.0
# 18  1998   A030301      年末总人口(万人)   124761  124761.0
# 19  1997   A030301      年末总人口(万人)   123626  123626.0

# %%
economy.disp_result(df, date_format="%Y")
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 人口结构（抚养比）
df, msg = economy.get_population_structure_y()
df = df[(df['indicator'] == 'A030305') | (df['indicator'] == 'A030306') | (df['indicator'] == 'A030307')]
df = df[df['date'] >= '1990']
economy.disp_result(df, date_format="%Y")
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %% [markdown]
# ## 数据接口 - 季度数据

# %%
# 季度GDP数据
df, msg = economy.get_gdp()
df = df[ (df['indicator'] == 'A010101') | (df['indicator'] == 'A010102')]
economy.disp_result(df, date_format='%YQ')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 季度GDP环比
df, msg = economy.get_gdp_q2q()
df = df[(df['date'] >= '2011')]
economy.disp_result(df, date_format='%YQ')
#print(df)

# %%
# 地区GDP(季度)
df, msg = economy.get_region_gdp('上海')
df_1 = df[df['indicator'] == 'A010101']
economy.disp_result(df_1, date_format='%YQ')
df_2 = df[df['indicator'] == 'A010103']
economy.disp_result(df_2, date_format='%YQ')

# %% [markdown]
# ## 数据接口 - 月度数据

# %%
# CPI月度数据（同比）
df, msg = economy.get_cpi()
df = df[(df['date'] >= '201701') & (df['value'] > 0) & (df['indicator'] == 'A01010101')]
df['value'] = df['value'].apply(lambda x : x - 100)
economy.disp_result(df, '%Y%m')

# %%
# CPI月度数据（同比，明细项）
df, msg = economy.get_cpi()
df = df[(df['date'] >= '201701') & (df['value'] > 0) & (df['indicator'] != 'A01010101')]
df['value'] = df['value'].apply(lambda x : x - 100)
economy.disp_result(df, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 区域CPI同比（上海）
df, msg = economy.get_region_cpi('上海')
df = df[(df['date'] >= '201701') & (df['value'] > 0) & (df['indicator'] == 'A01010101')]
economy.disp_result(df, '%Y%m')

# %%
# 月度PPI数据（同比）
df, msg = economy.get_ppi()
df = df[(df['value'] > 0)]
economy.disp_result(df, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 区域月度PPI数据
df, msg = economy.get_region_ppi('上海')
df = df[(df['value'] > 0)]
economy.disp_result(df, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 月度PMI数据（制造业）
df, msg = economy.get_manufacturing_pmi()
df = df[(df['value'] > 0) & (df['indicator'] == 'A190101')]
economy.disp_result(df, '%Y%m')

# %%
# 月度PMI数据（非制造业）
df, msg = economy.get_non_manufacturing_pmi()
df = df[(df['value'] > 0) & (df['indicator'] == 'A190201')]
economy.disp_result(df, '%Y%m')

# %%
# 月度PMI数据（综合PMI）
df, msg = economy.get_pmi()
df = df[(df['value'] > 0)]
economy.disp_result(df, '%Y%m')

# %%
# 月度进出口数据
df, msg = economy.get_import_export()
df = df[(df['value'] > 0) &
        ( (df['indicator'] == 'A160101') #| (df['indicator'] == 'A160103')
           | (df['indicator'] == 'A160105') #| (df['indicator'] == 'A160107')
           | (df['indicator'] == 'A160109') #| (df['indicator'] == 'A16010B')
           | (df['indicator'] == 'A16010D') #| (df['indicator'] == 'A16010E')
        )]
economy.disp_result(df, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 月度进出口同比增长
df, msg = economy.get_import_export()
df = df[(df['value'] > 0) &
        ( (df['indicator'] == 'A160102') #| (df['indicator'] == 'A160104')
           | (df['indicator'] == 'A160106') #| (df['indicator'] == 'A160108')
           | (df['indicator'] == 'A16010A') #| (df['indicator'] == 'A16010C')
        )]
    
economy.disp_result(df, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 月度FDI数据
df, msg = economy.get_fdi()
df_1 = df[ (df['value'] > 0) & (df['indicator'] == 'A16020B')]
economy.disp_result(df_1, '%Y%m')
df_2 = df[ (df['value'] > 0) & (df['indicator'] == 'A16020C')]
economy.disp_result(df_2, '%Y%m')

# %%
# 月度财政收入
df, msg = economy.get_fiscal_revenue()
df_1 = df[(df['value'] > 0) & ( (df['indicator'] == 'A1A0101') | (df['indicator'] == 'A1A0102'))]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] > 0) & (df['indicator'] == 'A1A0103')]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 月度财政支出
df, msg = economy.get_fiscal_expend()
df_1 = df[(df['value'] > 0) & ( (df['indicator'] == 'A1A0201') | (df['indicator'] == 'A1A0202'))]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] > 0) & (df['indicator'] == 'A1A0203')]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 货币发行量
df, msg = economy.get_M0_M1_M2()
df_1 = df[(df['value'] > 0) & ((df['indicator'] == 'A1B0101') | (df['indicator'] == 'A1B0103') | (df['indicator'] == 'A1B0105'))]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] > 0) & ((df['indicator'] == 'A1B0102') | (df['indicator'] == 'A1B0104') | (df['indicator'] == 'A1B0106'))]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 固定资产投资数据
df, msg = economy.get_fixed_asset_investment()
df_1 = df[(df['value'] > 0) & (df['indicator'] == 'A130101') ]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] > 0) & (df['indicator'] == 'A130102') ]
economy.disp_result(df_2, '%Y%m')

# %%
# 房地产开发投资
df, msg = economy.get_realestate_investment()
df_1 = df[(df['value'] > 0) & ( (df['indicator'] == 'A140101') | (df['indicator'] == 'A140107') | (df['indicator'] == 'A140109'))]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] > 0) & ( (df['indicator'] == 'A140102') | (df['indicator'] == 'A140108') | (df['indicator'] == 'A14010A'))]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 社会零售总额
import pandas as pd
df1, msg = economy.get_retail_sales()
df2, msg = economy.get_online_retail_sales()
df = pd.concat([df1, df2])
df_1 = df[(df['value'] > 0) & ( (df['indicator'] == 'A150101') | (df['indicator'] == 'A150102') | (df['indicator'] == 'A150801'))]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] > 0) & ( (df['indicator'] == 'A150103') | (df['indicator'] == 'A150104') | (df['indicator'] == 'A150802'))]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 70个大中城市房价指数(北京)
df, msg = economy.get_house_price_index('北京')
df_1 = df[(df['value'] != 0) & (
                                    (df['indicator'] == 'A010801') | (df['indicator'] == 'A010804') | (df['indicator'] == 'A010807') |
                                    (df['indicator'] == 'A01080A') | (df['indicator'] == 'A01080D') | (df['indicator'] == 'A01080G') |
                                    (df['indicator'] == 'A01080J') | (df['indicator'] == 'A01080M') | (df['indicator'] == 'A01080P')
)]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] != 0) & (
                                    (df['indicator'] == 'A010802') | (df['indicator'] == 'A010805') | (df['indicator'] == 'A010808') |
                                    (df['indicator'] == 'A01080B') | (df['indicator'] == 'A01080E') | (df['indicator'] == 'A01080H') |
                                    (df['indicator'] == 'A01080K') | (df['indicator'] == 'A01080N') | (df['indicator'] == 'A01080Q')
)]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)

# %%
# 70个大中城市房价指数(上海)
df, msg = economy.get_house_price_index('上海')
df_1 = df[(df['value'] != 0) & (
                                    (df['indicator'] == 'A010801') | (df['indicator'] == 'A010804') | (df['indicator'] == 'A010807') |
                                    (df['indicator'] == 'A01080A') | (df['indicator'] == 'A01080D') | (df['indicator'] == 'A01080G') |
                                    (df['indicator'] == 'A01080J') | (df['indicator'] == 'A01080M') | (df['indicator'] == 'A01080P')
)]
economy.disp_result(df_1, '%Y%m')
df_2 = df[(df['value'] != 0) & (
                                    (df['indicator'] == 'A010802') | (df['indicator'] == 'A010805') | (df['indicator'] == 'A010808') |
                                    (df['indicator'] == 'A01080B') | (df['indicator'] == 'A01080E') | (df['indicator'] == 'A01080H') |
                                    (df['indicator'] == 'A01080K') | (df['indicator'] == 'A01080N') | (df['indicator'] == 'A01080Q')
)]
economy.disp_result(df_2, '%Y%m')
# Out:
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df['date'] = sub_df['date'].apply(lambda x : convert_date(x, date_format))
# D:\QuantosFinanceTerminal\python\lib\site-packages\opendatatools\economy\economy_interface.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_df.sort_index(ascending=True, inplace=True)
